# %%
import pandas as pd

df = pd.read_csv('/content/drive/MyDrive/atm_transactions.csv')

df.head(5)
# Out:
#        atmId                  atmName atmCity  \
# 0  atm350000          ALİAĞA BAĞLI ŞB   Izmir
# 1  atm350001  ALİAĞA İSTİKLAL CADDESİ   Izmir
# 2  atm350002         ALİAĞA PAZARYERİ   Izmir
# 3  atm350003       ALİAĞA SAHİL PARKI   Izmir
# 4  atm350004            ALİAĞA ŞUBE-1   Izmir
#
#                          atmAddress  totalBalance  numberIncomeTransaction  \
# 0           Aliağa Petkim Tesisleri         40000                        0
# 1        ATATÜRK İSTİKLAL CD. NO:97         40000                        0
# 2        ALİAĞA KAPALI PAZAR GİRİŞİ         40000                        0
# 3  ALİAĞA HİKMET CD.SAHİL PARKI ÖNÜ         40000                        0
# 4       İstiklal Caddesi No: 64 / A         40000                        0
#
#    numberOutcomeTransaction  totalIncome  totalOutcome  \
# 0                         0            0             0
# 1                         0            0             0
# 2                         0            0             0
# ...

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30156 entries, 0 to 30155
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   atmId                     30156 non-null  object
#  1   atmName                   30156 non-null  object
#  2   atmCity                   30156 non-null  object
#  3   atmAddress                30156 non-null  object
#  4   totalBalance              30156 non-null  int64
#  5   numberIncomeTransaction   30156 non-null  int64
#  6   numberOutcomeTransaction  30156 non-null  int64
#  7   totalIncome               30156 non-null  int64
#  8   totalOutcome              30156 non-null  int64
#  9   totalNumberTransaction    30156 non-null  int64
#  10  day                       30156 non-null  object
#  11  transactionTime           30156 non-null  object
# dtypes: int64(6), object(6)
# memory usage: 2.8+ MB
# ...

# %%
print(df.isnull().sum())
# Out:
# atmId                       0
# atmName                     0
# atmCity                     0
# atmAddress                  0
# totalBalance                0
# numberIncomeTransaction     0
# numberOutcomeTransaction    0
# totalIncome                 0
# totalOutcome                0
# totalNumberTransaction      0
# day                         0
# transactionTime             0
# dtype: int64

# %%
atms_with_zero_transactions = df[df['totalNumberTransaction'] == 0]

print("ATMs without transactions:")
atms_with_zero_transactions
# Out:
# ATMs without transactions:
#              atmId                    atmName atmCity  \
# 0        atm350000            ALİAĞA BAĞLI ŞB   Izmir
# 1        atm350001    ALİAĞA İSTİKLAL CADDESİ   Izmir
# 2        atm350002           ALİAĞA PAZARYERİ   Izmir
# 3        atm350003         ALİAĞA SAHİL PARKI   Izmir
# 4        atm350004              ALİAĞA ŞUBE-1   Izmir
# ...            ...                        ...     ...
# 18237  atm35000287  KONAK METRO İSTASYONU ATM   Izmir
# 22723   atm3500071        HAŞİM İŞCAN CADDESİ   Izmir
# 26574    atm350008       STAR RAFİNERİ ALİAĞA   Izmir
# 26737  atm35000136   ÇİĞLİ BÖL.ARAŞ.HASTANESİ   Izmir
# 27254  atm35000329              ÖDEMİŞ MEYDAN   Izmir
#
#                                          atmAddress  totalBalance  \
# 0                           Aliağa Petkim Tesisleri         40000
# 1                        ATATÜRK İSTİKLAL CD. NO:97         40000
# 2                        ALİAĞA KAPALI PAZAR GİRİŞİ         40000
# ...

# %%
atms_with_zero_balance = df[df['totalBalance'] == 0]

print("ATMs with 0 balance:")

atms_with_zero_balance.shape[0]
atms_with_zero_balance
# Out:
# ATMs with 0 balance:
#              atmId              atmName atmCity  \
# 6825     atm350004        ALİAĞA ŞUBE-1   Izmir
# 7346   atm35000131  DALYAN ÇEŞME DÜKKAN   Izmir
# 7390   atm35000175          BOZYAKA SGK   Izmir
# 7458   atm35000278   KARATAŞ MİTHATPAŞA   Izmir
# 10228  atm35000141         ÇİĞLİ ŞUBE-2   Izmir
# ...            ...                  ...     ...
# 29221  atm35000107    OTOKENT BUCA MAH.   Izmir
# 29257  atm35000143       DYO BOYA ÇİĞLİ   Izmir
# 29656  atm35000183    KARABAĞLAR ÇAMLIK   Izmir
# 29952  atm35000120       ALAÇATI MERKEZ   Izmir
# 30059  atm35000227        MAVİBAHÇE AVM   Izmir
#
#                                      atmAddress  totalBalance  \
# 6825                İstiklal Caddesi No: 64 / A             0
# 7346             DALYAN MAHALLESİ 4218. SK. 49A             0
# 7390          SAİM ÇIKRIKÇI CD.BOZYAKA SGK YANI             0
# 7458             MİTHATPAŞA CD.NO:189/A KARATAŞ             0
# ...

# %% [markdown]
# These ATMs are without balance in these days and timestamp. This issue must be addressed so that they can improve their services.

# %%
sort = df.sort_values(by='totalNumberTransaction', ascending=True)
sort
# Out:
#              atmId                atmName atmCity  \
# 0        atm350000        ALİAĞA BAĞLI ŞB   Izmir
# 70     atm35000260     BUCA DOĞUŞ CADDESİ   Izmir
# 69     atm35000259        BASMANE ŞUBE-2-   Izmir
# 68     atm35000258        BASMANE ŞUBE-1-   Izmir
# 67     atm35000257              BASMANE-1   Izmir
# ...            ...                    ...     ...
# 15677  atm35000205       DEMİRKÖPRÜ METRO   Izmir
# 11263   atm3500099  BUCA MENDERES CADDESİ   Izmir
# 10337  atm35000285     KONAK GAZİ CADDESİ   Izmir
# 3170   atm35000298             SWISS OTEL   Izmir
# 20809  atm35000346           KİPA TORBALI   Izmir
#
#                                               atmAddress  totalBalance  \
# 0                                Aliağa Petkim Tesisleri         40000
# 70     DOKUZ EYLÜL ÜNİVERSİTESİ TINAZTEPE YERLEŞKESİ ...         40000
# 69       İsmet Kaptan Mahallesi Fevzipaşa Bulvarı No:123         40000
# 68       İsmet Kaptan Mahallesi Fevzipaşa Bulvarı No:123         40000
# ...

# %%
duplicates = df[df.duplicated()]

# Print duplicates, if any
if duplicates.empty:
    print("No duplicates found.")
else:
    print("Duplicate rows:")
    print(duplicates)
# Out:
# No duplicates found.

# %%
num_unique_atm_ids = df['atmId'].nunique()

print(f'The number of unique ATM IDs is: {num_unique_atm_ids}')
# Out:
# The number of unique ATM IDs is: 359

# %%
num_unique_locations = df['atmAddress'].nunique()

print(f'The number of unique locations (unique atmAddress) is: {num_unique_locations}')
# Out:
# The number of unique locations (unique atmAddress) is: 717

# %%
atms_with_balance = df[df['totalBalance'] ==0 &]

atms_with_balance
# Out:
#              atmId                  atmName atmCity  \
# 0        atm350000          ALİAĞA BAĞLI ŞB   Izmir
# 1        atm350001  ALİAĞA İSTİKLAL CADDESİ   Izmir
# 2        atm350002         ALİAĞA PAZARYERİ   Izmir
# 3        atm350003       ALİAĞA SAHİL PARKI   Izmir
# 4        atm350004            ALİAĞA ŞUBE-1   Izmir
# ...            ...                      ...     ...
# 30151  atm35000354           TORBALI ŞUBE-2   Izmir
# 30152  atm35000355              URLA İSKELE   Izmir
# 30153  atm35000356      URLA MEYDAN AVM ÖNÜ   Izmir
# 30154  atm35000357              URLA ŞUBE-1   Izmir
# 30155  atm35000358              URLA ŞUBE-2   Izmir
#
#                                               atmAddress  totalBalance  \
# 0                                Aliağa Petkim Tesisleri         40000
# 1                             ATATÜRK İSTİKLAL CD. NO:97         40000
# 2                             ALİAĞA KAPALI PAZAR GİRİŞİ         40000
# ...

# %%
balance_but_no_transacetion = atms_with_balance[atms_with_balance['totalNumberTransaction'] == 0]

balance_but_no_transacetion
# Out:
#              atmId                    atmName atmCity  \
# 0        atm350000            ALİAĞA BAĞLI ŞB   Izmir
# 1        atm350001    ALİAĞA İSTİKLAL CADDESİ   Izmir
# 2        atm350002           ALİAĞA PAZARYERİ   Izmir
# 3        atm350003         ALİAĞA SAHİL PARKI   Izmir
# 4        atm350004              ALİAĞA ŞUBE-1   Izmir
# ...            ...                        ...     ...
# 18237  atm35000287  KONAK METRO İSTASYONU ATM   Izmir
# 22723   atm3500071        HAŞİM İŞCAN CADDESİ   Izmir
# 26574    atm350008       STAR RAFİNERİ ALİAĞA   Izmir
# 26737  atm35000136   ÇİĞLİ BÖL.ARAŞ.HASTANESİ   Izmir
# 27254  atm35000329              ÖDEMİŞ MEYDAN   Izmir
#
#                                          atmAddress  totalBalance  \
# 0                           Aliağa Petkim Tesisleri         40000
# 1                        ATATÜRK İSTİKLAL CD. NO:97         40000
# 2                        ALİAĞA KAPALI PAZAR GİRİŞİ         40000
# ...

# %%
filtered_df = df[(df['totalBalance'] > 0) & (df['totalNumberTransaction'] > 0)]

# Number of remaining rows after filtering
remaining_rows = filtered_df.shape[0]

print(f'The number of remaining rows after filtering is: {remaining_rows}')
filtered_df
# Out:
# The number of remaining rows after filtering is: 29947
#              atmId                    atmName atmCity  \
# 74     atm35000264    GÖZTEPE MİTHATPAŞA CAD.   Izmir
# 75      atm3500036    BERGAMA ATATÜRK BULVARI   Izmir
# 76      atm3500037  BERGAMA İNKİLAP MAHALLESİ   Izmir
# 77      atm3500038             BERGAMA MEYDAN   Izmir
# 78      atm3500039             BERGAMA ŞUBE-1   Izmir
# ...            ...                        ...     ...
# 30151  atm35000354             TORBALI ŞUBE-2   Izmir
# 30152  atm35000355                URLA İSKELE   Izmir
# 30153  atm35000356        URLA MEYDAN AVM ÖNÜ   Izmir
# 30154  atm35000357                URLA ŞUBE-1   Izmir
# 30155  atm35000358                URLA ŞUBE-2   Izmir
#
#                                               atmAddress  totalBalance  \
# 74     GOZTEPE MAHALLESİ,40000,0,0,0,0,0,Wednesday,20...         39490
# 75                        MALTEPE MH.ATATÜRK BUL.BERGAMA         39760
# ...

# %%
filtered_df = df[(df['totalBalance'] > 0) & (df['totalNumberTransaction'] > 0)]

remaining_rows = filtered_df.shape[0]

print(f'The number of remaining rows after filtering is: {remaining_rows}')
filtered_df
# Out:
# The number of remaining rows after filtering is: 29947
#              atmId                    atmName atmCity  \
# 74     atm35000264    GÖZTEPE MİTHATPAŞA CAD.   Izmir
# 75      atm3500036    BERGAMA ATATÜRK BULVARI   Izmir
# 76      atm3500037  BERGAMA İNKİLAP MAHALLESİ   Izmir
# 77      atm3500038             BERGAMA MEYDAN   Izmir
# 78      atm3500039             BERGAMA ŞUBE-1   Izmir
# ...            ...                        ...     ...
# 30151  atm35000354             TORBALI ŞUBE-2   Izmir
# 30152  atm35000355                URLA İSKELE   Izmir
# 30153  atm35000356        URLA MEYDAN AVM ÖNÜ   Izmir
# 30154  atm35000357                URLA ŞUBE-1   Izmir
# 30155  atm35000358                URLA ŞUBE-2   Izmir
#
#                                               atmAddress  totalBalance  \
# 74     GOZTEPE MAHALLESİ,40000,0,0,0,0,0,Wednesday,20...         39490
# 75                        MALTEPE MH.ATATÜRK BUL.BERGAMA         39760
# ...

# %%
sorted_incomeTransaction = df.sort_values(by='totalIncome', ascending=False)

print("Sorted DataFrame by numberIncomeTransaction:")
sorted_incomeTransaction
# Out:
# Sorted DataFrame by numberIncomeTransaction:
#              atmId                    atmName atmCity  \
# 8520   atm35000228  MAVİŞEHİR ALBATROS SİTESİ   Izmir
# 28839   atm3500084           PINARBAŞI ŞUBE-1   Izmir
# 3650   atm35000250       ALSANCAK İZBAN METRO   Izmir
# 28799   atm3500040             BERGAMA ŞUBE-2   Izmir
# 12110  atm35000228  MAVİŞEHİR ALBATROS SİTESİ   Izmir
# ...            ...                        ...     ...
# 21680  atm35000105         GÖKSU MH.637/4 SK.   Izmir
# 21631   atm3500052               BORNOVA KİPA   Izmir
# 21630   atm3500051  BORNOVA KAZIM K.BEKİR CAD   Izmir
# 21626   atm3500047    BAYRAKLI FOLKART TOWERS   Izmir
# 0        atm350000            ALİAĞA BAĞLI ŞB   Izmir
#
#                                               atmAddress  totalBalance  \
# 8520                           ALBATROS SİTESİ MAVİŞEHİR         21630
# 28839                     Pınar Caddesi No: 93 Pınarbaşı          6765
# ...

# %%
sorted_outcomeTransaction = df.sort_values(by='totalOutcome', ascending=False)

print("Sorted DataFrame by numberOutcomeTransaction:")
sorted_outcomeTransaction
# Out:
# Sorted DataFrame by numberOutcomeTransaction:
#              atmId                    atmName atmCity  \
# 27365   atm3500042       2.SANAYİ SİTESİ ŞB-2   Izmir
# 28564  atm35000168          İZMİR OPTİMUM AVM   Izmir
# 28624  atm35000228  MAVİŞEHİR ALBATROS SİTESİ   Izmir
# 20315  atm35000176             BOZYAKA ŞUBE-1   Izmir
# 10466  atm35000245            PEPSİ KEMALPAŞA   Izmir
# ...            ...                        ...     ...
# 18262  atm35000312               ERNİŞ PETROL   Izmir
# 4437    atm3500094         BUCA ERDEM CADDESİ   Izmir
# 13281  atm35000357                URLA ŞUBE-1   Izmir
# 5483    atm3500059             BORNOVA ŞUBE-3   Izmir
# 0        atm350000            ALİAĞA BAĞLI ŞB   Izmir
#
#                                               atmAddress  totalBalance  \
# 27365             Kazımdirik Mahallesi 351 Sokak No: 3 B         34800
# 28564                               OPTİMUM AVM GAZİEMİR         22605
# ...

# %% [markdown]
# Here the dataframe is sorted on total outcome. That means the ones on the top positions need to be monitored and recharged properly.

# %%
# Out:
# Rows where there are no transactions after 10 PM:
# Empty DataFrame
# Columns: [atmId, atmName, atmCity, atmAddress, totalBalance, numberIncomeTransaction, numberOutcomeTransaction, totalIncome, totalOutcome, totalNumberTransaction, day, transactionTime]
# Index: []
